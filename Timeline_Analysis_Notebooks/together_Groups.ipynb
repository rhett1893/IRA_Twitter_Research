# %%
import csv
import numpy as np 
import pandas as pd
from datetime import datetime as dt
import matplotlib
import matplotlib.pyplot as plt 
import pickle
import statistics
import sys
import glob

pd.set_option('display.max_rows', 4000)
pd.set_option('display.max_columns', 200)

# %%
def normalizing_funtion(df_1, df_2):
    normalized_df = df_1
    top_df = df_1
    bottom_df = df_2

    for i in range(len(bottom_df)):
    #     for each row (user)
        temp_list = []
        for j in (normalized_df.columns):
    #         for each column (month)
            top_total = top_df[j][i]
            bottom_total = bottom_df[j][i]
            if pd.isnull(bottom_total):
                temp_list.append(np.nan)
            elif top_total == 0 or bottom_total == 0:
                temp_list.append(0)
            else:
                if pd.isnull((top_total/bottom_total)):
                    temp_list.append(0)
                else:
                    temp_list.append((top_total/bottom_total))

        normalized_df['01-2009'][i] = temp_list[0]
        normalized_df['02-2009'][i] = temp_list[1]
        normalized_df['03-2009'][i] = temp_list[2]
        normalized_df['04-2009'][i] = temp_list[3]
        normalized_df['05-2009'][i] = temp_list[4]
        normalized_df['06-2009'][i] = temp_list[5]
        normalized_df['07-2009'][i] = temp_list[6]
        normalized_df['08-2009'][i] = temp_list[7]
        normalized_df['09-2009'][i] = temp_list[8]
        normalized_df['10-2009'][i] = temp_list[9]
        normalized_df['11-2009'][i] = temp_list[10]
        normalized_df['12-2009'][i] = temp_list[11]
        normalized_df['01-2010'][i] = temp_list[12]
        normalized_df['02-2010'][i] = temp_list[13]
        normalized_df['03-2010'][i] = temp_list[14]
        normalized_df['04-2010'][i] = temp_list[15]
        normalized_df['05-2010'][i] = temp_list[16]
        normalized_df['06-2010'][i] = temp_list[17]
        normalized_df['07-2010'][i] = temp_list[18]
        normalized_df['08-2010'][i] = temp_list[19]
        normalized_df['09-2010'][i] = temp_list[20]
        normalized_df['10-2010'][i] = temp_list[21]
        normalized_df['11-2010'][i] = temp_list[22]
        normalized_df['12-2010'][i] = temp_list[23]
        normalized_df['01-2011'][i] = temp_list[24]
        normalized_df['02-2011'][i] = temp_list[25]
        normalized_df['03-2011'][i] = temp_list[26]
        normalized_df['04-2011'][i] = temp_list[27]
        normalized_df['05-2011'][i] = temp_list[28]
        normalized_df['06-2011'][i] = temp_list[29]
        normalized_df['07-2011'][i] = temp_list[30]
        normalized_df['08-2011'][i] = temp_list[31]
        normalized_df['09-2011'][i] = temp_list[32]
        normalized_df['10-2011'][i] = temp_list[33]
        normalized_df['11-2011'][i] = temp_list[34]
        normalized_df['12-2011'][i] = temp_list[35]
        normalized_df['01-2012'][i] = temp_list[36]
        normalized_df['02-2012'][i] = temp_list[37]
        normalized_df['03-2012'][i] = temp_list[38]
        normalized_df['04-2012'][i] = temp_list[39]
        normalized_df['05-2012'][i] = temp_list[40]
        normalized_df['06-2012'][i] = temp_list[41]
        normalized_df['07-2012'][i] = temp_list[42]
        normalized_df['08-2012'][i] = temp_list[43]
        normalized_df['09-2012'][i] = temp_list[44]
        normalized_df['10-2012'][i] = temp_list[45]
        normalized_df['11-2012'][i] = temp_list[46]
        normalized_df['12-2012'][i] = temp_list[47]
        normalized_df['01-2013'][i] = temp_list[48]
        normalized_df['02-2013'][i] = temp_list[49]
        normalized_df['03-2013'][i] = temp_list[50]
        normalized_df['04-2013'][i] = temp_list[51]
        normalized_df['05-2013'][i] = temp_list[52]
        normalized_df['06-2013'][i] = temp_list[53]
        normalized_df['07-2013'][i] = temp_list[54]
        normalized_df['08-2013'][i] = temp_list[55]
        normalized_df['09-2013'][i] = temp_list[56]
        normalized_df['10-2013'][i] = temp_list[57]
        normalized_df['11-2013'][i] = temp_list[58]
        normalized_df['12-2013'][i] = temp_list[59]
        normalized_df['01-2014'][i] = temp_list[60]
        normalized_df['02-2014'][i] = temp_list[61]
        normalized_df['03-2014'][i] = temp_list[62]
        normalized_df['04-2014'][i] = temp_list[63]
        normalized_df['05-2014'][i] = temp_list[64]
        normalized_df['06-2014'][i] = temp_list[65]
        normalized_df['07-2014'][i] = temp_list[66]
        normalized_df['08-2014'][i] = temp_list[67]
        normalized_df['09-2014'][i] = temp_list[68]
        normalized_df['10-2014'][i] = temp_list[69]
        normalized_df['11-2014'][i] = temp_list[70]
        normalized_df['12-2014'][i] = temp_list[71]
        normalized_df['01-2015'][i] = temp_list[72]
        normalized_df['02-2015'][i] = temp_list[73]
        normalized_df['03-2015'][i] = temp_list[74]
        normalized_df['04-2015'][i] = temp_list[75]
        normalized_df['05-2015'][i] = temp_list[76]
        normalized_df['06-2015'][i] = temp_list[77]
        normalized_df['07-2015'][i] = temp_list[78]
        normalized_df['08-2015'][i] = temp_list[79]
        normalized_df['09-2015'][i] = temp_list[80]
        normalized_df['10-2015'][i] = temp_list[81]
        normalized_df['11-2015'][i] = temp_list[82]
        normalized_df['12-2015'][i] = temp_list[83]
        normalized_df['01-2016'][i] = temp_list[84]
        normalized_df['02-2016'][i] = temp_list[85]
        normalized_df['03-2016'][i] = temp_list[86]
        normalized_df['04-2016'][i] = temp_list[87]
        normalized_df['05-2016'][i] = temp_list[88]
        normalized_df['06-2016'][i] = temp_list[89]
        normalized_df['07-2016'][i] = temp_list[90]
        normalized_df['08-2016'][i] = temp_list[91]
        normalized_df['09-2016'][i] = temp_list[92]
        normalized_df['10-2016'][i] = temp_list[93]
        normalized_df['11-2016'][i] = temp_list[94]
        normalized_df['12-2016'][i] = temp_list[95]
    
    return normalized_df

# %% [markdown]
# **Random Baseline**

# %%
rb_df = pd.read_pickle("./RB_timelineDF_090320.pkl")
rb_tweet_countDF = pd.read_pickle("./RB_tweet_countDF_090320.pkl")
rb_trump_countDF = pd.read_pickle("./RB_trump_countDF_090320.pkl")
rb_clinton_countDF = pd.read_pickle("./RB_clinton_countDF_090320.pkl")
rb_sentiment_scoresDF = pd.read_pickle("./RB_sentiment_scoresDF_090320.pkl")
rb_trump_sentDF = pd.read_pickle("./RB_trump_sentDF_090320.pkl")
rb_clinton_sentDF = pd.read_pickle("./RB_clinton_sentDF_090320.pkl")
rb_positive_sentDF = pd.read_pickle("./RB_positive_sentDF_090320.pkl")
rb_negative_sentDF = pd.read_pickle("./RB_negative_sentDF_090320.pkl")

# %%
len(rb_tweet_countDF)
# Out:
# 8016

# %%
list1=[1,2,4,5]

# %%
list2 = list1[:-2]

# %%
list2
# Out:
# [1, 2]

# %% [markdown]
# **GEN_RES**

# %%
GEN_RES_tweet_countDF = pd.read_pickle("./GEN_RES_tweet_countDF_100420.pkl")
GEN_RES_trump_countDF = pd.read_pickle("./GEN_RES_trump_countDF_100420.pkl")
GEN_RES_clinton_countDF = pd.read_pickle("./GEN_RES_clinton_countDF_100420.pkl")
GEN_RES_sentiment_scoresDF = pd.read_pickle("./GEN_RES_sentiment_scoresDF_100420.pkl")
GEN_RES_trump_sentDF = pd.read_pickle("./GEN_RES_trump_sentDF_100420.pkl")
GEN_RES_clinton_sentDF = pd.read_pickle("./GEN_RES_clinton_sentDF_100420.pkl")
GEN_RES_positive_sentDF = pd.read_pickle("./GEN_RES_positive_sentDF_100420.pkl")
GEN_RES_negative_sentDF = pd.read_pickle("./GEN_RES_negative_sentDF_100420.pkl")

# %% [markdown]
# **GEN_UNRES**

# %%
GEN_UNRES_tweet_countDF = pd.read_pickle("./GEN_UNRES_tweet_countDF_100420.pkl")
GEN_UNRES_trump_countDF = pd.read_pickle("./GEN_UNRES_trump_countDF_100420.pkl")
GEN_UNRES_clinton_countDF = pd.read_pickle("./GEN_UNRES_clinton_countDF_100420.pkl")
GEN_UNRES_sentiment_scoresDF = pd.read_pickle("./GEN_UNRES_sentiment_scoresDF_100420.pkl")
GEN_UNRES_trump_sentDF = pd.read_pickle("./GEN_UNRES_trump_sentDF_100420.pkl")
GEN_UNRES_clinton_sentDF = pd.read_pickle("./GEN_UNRES_clinton_sentDF_100420.pkl")
GEN_UNRES_positive_sentDF = pd.read_pickle("./GEN_UNRES_positive_sentDF_100420.pkl")
GEN_UNRES_negative_sentDF = pd.read_pickle("./GEN_UNRES_negative_sentDF_100420.pkl")

# %% [markdown]
# **INF_RES**

# %%
INF_RES_tweet_countDF = pd.read_pickle("./INF_RES_tweet_countDF_100420.pkl")
INF_RES_trump_countDF = pd.read_pickle("./INF_RES_trump_countDF_100420.pkl")
INF_RES_clinton_countDF = pd.read_pickle("./INF_RES_clinton_countDF_100420.pkl")
INF_RES_sentiment_scoresDF = pd.read_pickle("./INF_RES_sentiment_scoresDF_100420.pkl")
INF_RES_trump_sentDF = pd.read_pickle("./INF_RES_trump_sentDF_100420.pkl")
INF_RES_clinton_sentDF = pd.read_pickle("./INF_RES_clinton_sentDF_100420.pkl")
INF_RES_positive_sentDF = pd.read_pickle("./INF_RES_positive_sentDF_100420.pkl")
INF_RES_negative_sentDF = pd.read_pickle("./INF_RES_negative_sentDF_100420.pkl")

# %% [markdown]
# **INF_UNRES**

# %%
INF_UNRES_tweet_countDF = pd.read_pickle("./INF_UNRES_tweet_countDF_100420.pkl")
INF_UNRES_trump_countDF = pd.read_pickle("./INF_UNRES_trump_countDF_100420.pkl")
INF_UNRES_clinton_countDF = pd.read_pickle("./INF_UNRES_clinton_countDF_100420.pkl")
INF_UNRES_sentiment_scoresDF = pd.read_pickle("./INF_UNRES_sentiment_scoresDF_100420.pkl")
INF_UNRES_trump_sentDF = pd.read_pickle("./INF_UNRES_trump_sentDF_100420.pkl")
INF_UNRES_clinton_sentDF = pd.read_pickle("./INF_UNRES_clinton_sentDF_100420.pkl")
INF_UNRES_positive_sentDF = pd.read_pickle("./INF_UNRES_positive_sentDF_100420.pkl")
INF_UNRES_negative_sentDF = pd.read_pickle("./INF_UNRES_negative_sentDF_100420.pkl")

# %% [markdown]
# **Tweet Count**

# %%
# plt.figure()

# rb_tweet_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Tweet Volume')
# Q1_tweet_countDF.mean().plot(kind='line', color='blue', figsize=(15,8))
# Q2_tweet_countDF.mean().plot(kind='line', color='purple', figsize=(15,8))
# Q3_tweet_countDF.mean().plot(kind='line', color='darkblue', figsize=(15,8))
# Q4_tweet_countDF.mean().plot(kind='line', color='black', figsize=(15,8))

# plt.legend(('Random Baseline','Q1 - Targeted Users', 'Q2- Targeted Users','Q3- Targeted Users','Q4- Targeted Users'))
# plt.ylabel('Mean Monthly Tweets')
# plt.xlabel('Timeline')
# plt.show()

# %%
# plt.figure()

# rb_trump_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Trump Mentions')
# Q1_trump_countDF.mean().plot(kind='line', color='blue')
# Q2_trump_countDF.mean().plot(kind='line', color='purple')
# Q3_trump_countDF.mean().plot(kind='line', color='darkblue')
# Q4_trump_countDF.mean().plot(kind='line', color='black')


# plt.legend(('Random Baseline','Q1 - Targeted Users', 'Q2- Targeted Users','Q3- Targeted Users','Q4- Targeted Users'))
# plt.ylabel('Mean Monthly Mentions')
# plt.xlabel('Timeline')
# plt.show()

# %%
# plt.figure()

# rb_clinton_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Clinton Mentions')
# Q1_clinton_countDF.mean().plot(kind='line', color='blue')
# Q2_clinton_countDF.mean().plot(kind='line', color='purple')
# Q3_clinton_countDF.mean().plot(kind='line', color='darkblue')
# Q4_clinton_countDF.mean().plot(kind='line', color='black')

# plt.ylim(top=25, bottom=0)
# plt.legend(('Random Baseline','Q1 - Targeted Users', 'Q2- Targeted Users','Q3- Targeted Users','Q4- Targeted Users'))
# plt.ylabel('Mean Monthly Mentions')
# plt.xlabel('Timeline')
# plt.show()

# %%
plt.figure()

rb_clinton_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Clinton Mentions')
GEN_RES_clinton_countDF.mean().plot(kind='line', color='blue')
GEN_UNRES_clinton_countDF.mean().plot(kind='line', color='purple')
INF_RES_clinton_countDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_clinton_countDF.mean().plot(kind='line', color='black')

plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Mentions')
plt.xlabel('Timeline')
plt.show()

# %%
rb_normalized_trumpDF = normalizing_funtion(rb_trump_countDF, rb_tweet_countDF)
rb_normalized_clintonDF = normalizing_funtion(rb_clinton_countDF, rb_tweet_countDF)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
GEN_RES_normalized_trumpDF = normalizing_funtion(GEN_RES_trump_countDF, GEN_RES_tweet_countDF)
GEN_RES_normalized_clintonDF = normalizing_funtion(GEN_RES_clinton_countDF, GEN_RES_tweet_countDF)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
GEN_UNRES_normalized_trumpDF = normalizing_funtion(GEN_UNRES_trump_countDF, GEN_UNRES_tweet_countDF)
GEN_UNRES_normalized_clintonDF = normalizing_funtion(GEN_UNRES_clinton_countDF, GEN_UNRES_tweet_countDF)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
INF_RES_normalized_trumpDF = normalizing_funtion(INF_RES_trump_countDF, INF_RES_tweet_countDF)
INF_RES_normalized_clintonDF = normalizing_funtion(INF_RES_clinton_countDF, INF_RES_tweet_countDF)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
INF_UNRES_normalized_trumpDF = normalizing_funtion(INF_UNRES_trump_countDF, INF_UNRES_tweet_countDF)
INF_UNRES_normalized_clintonDF = normalizing_funtion(INF_UNRES_clinton_countDF, INF_UNRES_tweet_countDF)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
def shorten_DF(dataframe):
    dataframe = dataframe.drop(columns=['01-2009', '02-2009', '03-2009', '04-2009', '05-2009', '06-2009',
       '07-2009', '08-2009', '09-2009', '10-2009', '11-2009', '12-2009',
       '01-2010', '02-2010', '03-2010', '04-2010', '05-2010', '06-2010',
       '07-2010', '08-2010', '09-2010', '10-2010', '11-2010', '12-2010',
       '01-2011', '02-2011', '03-2011', '04-2011', '05-2011', '06-2011',
       '07-2011', '08-2011', '09-2011', '10-2011', '11-2011', '12-2011',
       '01-2012', '02-2012', '03-2012', '04-2012', '05-2012', '06-2012',
       '07-2012', '08-2012', '09-2012', '10-2012', '11-2012', '12-2012',
       '01-2013', '02-2013', '03-2013', '04-2013', '05-2013', '06-2013',
       '07-2013', '08-2013', '09-2013', '10-2013', '11-2013', '12-2013'])
    return dataframe

# %%
GEN_RES_tweet_countDF = shorten_DF(GEN_RES_tweet_countDF)
GEN_RES_trump_countDF = shorten_DF(GEN_RES_trump_countDF)
GEN_RES_clinton_countDF = shorten_DF(GEN_RES_clinton_countDF)
GEN_RES_sentiment_scoresDF = shorten_DF(GEN_RES_sentiment_scoresDF)
GEN_RES_trump_sentDF = shorten_DF(GEN_RES_trump_sentDF)
GEN_RES_clinton_sentDF = shorten_DF(GEN_RES_clinton_sentDF)
GEN_RES_positive_sentDF = shorten_DF(GEN_RES_positive_sentDF)
GEN_RES_negative_sentDF = shorten_DF(GEN_RES_negative_sentDF)


GEN_UNRES_tweet_countDF = shorten_DF(GEN_UNRES_tweet_countDF)
GEN_UNRES_trump_countDF = shorten_DF(GEN_UNRES_trump_countDF)
GEN_UNRES_clinton_countDF = shorten_DF(GEN_UNRES_clinton_countDF)
GEN_UNRES_sentiment_scoresDF = shorten_DF(GEN_UNRES_sentiment_scoresDF)
GEN_UNRES_trump_sentDF = shorten_DF(GEN_UNRES_trump_sentDF)
GEN_UNRES_clinton_sentDF = shorten_DF(GEN_UNRES_clinton_sentDF)
GEN_UNRES_positive_sentDF = shorten_DF(GEN_UNRES_positive_sentDF)
GEN_UNRES_negative_sentDF = shorten_DF(GEN_UNRES_negative_sentDF)


INF_RES_tweet_countDF = shorten_DF(INF_RES_tweet_countDF)
INF_RES_trump_countDF = shorten_DF(INF_RES_trump_countDF)
INF_RES_clinton_countDF = shorten_DF(INF_RES_clinton_countDF)
INF_RES_sentiment_scoresDF = shorten_DF(INF_RES_sentiment_scoresDF)
INF_RES_trump_sentDF = shorten_DF(INF_RES_trump_sentDF)
INF_RES_clinton_sentDF = shorten_DF(INF_RES_clinton_sentDF)
INF_RES_positive_sentDF = shorten_DF(INF_RES_positive_sentDF)
INF_RES_negative_sentDF = shorten_DF(INF_RES_negative_sentDF)


INF_UNRES_tweet_countDF = shorten_DF(INF_UNRES_tweet_countDF)
INF_UNRES_trump_countDF = shorten_DF(INF_UNRES_trump_countDF)
INF_UNRES_clinton_countDF = shorten_DF(INF_UNRES_clinton_countDF)
INF_UNRES_sentiment_scoresDF = shorten_DF(INF_UNRES_sentiment_scoresDF)
INF_UNRES_trump_sentDF = shorten_DF(INF_UNRES_trump_sentDF)
INF_UNRES_clinton_sentDF = shorten_DF(INF_UNRES_clinton_sentDF)
INF_UNRES_positive_sentDF = shorten_DF(INF_UNRES_positive_sentDF)
INF_UNRES_negative_sentDF = shorten_DF(INF_UNRES_negative_sentDF)

# %%
rb_tweet_countDF = shorten_DF(rb_tweet_countDF)
rb_trump_countDF = shorten_DF(rb_trump_countDF)
rb_clinton_countDF = shorten_DF(rb_clinton_countDF)
rb_sentiment_scoresDF = shorten_DF(rb_sentiment_scoresDF)
rb_trump_sentDF = shorten_DF(rb_trump_sentDF)
rb_clinton_sentDF = shorten_DF(rb_clinton_sentDF)
rb_positive_sentDF = shorten_DF(rb_positive_sentDF)
rb_negative_sentDF = shorten_DF(rb_negative_sentDF)

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 14}

matplotlib.rc('font', **font)

# %% [markdown]
# **Tweet Count**

# %%
plt.figure()

rb_tweet_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Tweet Volume')
GEN_RES_tweet_countDF.mean().plot(kind='line', color='blue', figsize=(15,8))
GEN_UNRES_tweet_countDF.mean().plot(kind='line', color='purple', figsize=(15,8))
INF_RES_tweet_countDF.mean().plot(kind='line', color='darkblue', figsize=(15,8))
INF_UNRES_tweet_countDF.mean().plot(kind='line', color='black', figsize=(15,8))

plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Tweets')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %% [markdown]
# **Trump Mentions**

# %%
plt.figure()

rb_trump_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Normalized Mean Monthly Trump Mentions')
GEN_RES_trump_countDF.mean().plot(kind='line', color='blue')
GEN_UNRES_trump_countDF.mean().plot(kind='line', color='purple')
INF_RES_trump_countDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_trump_countDF.mean().plot(kind='line', color='black')


plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Normalized Mean Monthly Mentions')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %%
plt.figure()

rb_normalized_trumpDF.mean().plot(kind='line', color='green', figsize=(15,8),title=' NORMALIZED Mean Monthly Trump Mentions')
GEN_RES_normalized_trumpDF.mean().plot(kind='line', color='blue')
GEN_UNRES_normalized_trumpDF.mean().plot(kind='line', color='purple')
INF_RES_normalized_trumpDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_normalized_trumpDF.mean().plot(kind='line', color='black')

plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Mentions')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %% [markdown]
# **Clinton Count**

# %%
plt.figure()

rb_clinton_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Normalized Mean Monthly Clinton Mentions')
GEN_RES_clinton_countDF.mean().plot(kind='line', color='blue')
GEN_UNRES_clinton_countDF.mean().plot(kind='line', color='purple')
INF_RES_clinton_countDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_clinton_countDF.mean().plot(kind='line', color='black')

# plt.ylim(top=25, bottom=0)
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Normalized Mean Monthly Mentions')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %%
plt.figure()

rb_clinton_countDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Clinton Mentions')
GEN_RES_clinton_countDF.mean().plot(kind='line', color='blue')
GEN_UNRES_clinton_countDF.mean().plot(kind='line', color='purple')
INF_RES_clinton_countDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_clinton_countDF.mean().plot(kind='line', color='black')

# plt.ylim(top=25, bottom=0)
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Mentions')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %%
plt.figure()

rb_normalized_clintonDF.mean().plot(kind='line', color='green', figsize=(15,8),title=' NORMALIZED Mean Monthly Clinton Mentions')
GEN_RES_normalized_clintonDF.mean().plot(kind='line', color='blue')
GEN_UNRES_normalized_clintonDF.mean().plot(kind='line', color='purple')
INF_RES_normalized_clintonDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_normalized_clintonDF.mean().plot(kind='line', color='black')


plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Mentions')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %% [markdown]
# **Trump Sentiment**

# %%
plt.figure()

rb_trump_sentDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Trump Mention Sentiment')
GEN_RES_trump_sentDF.mean().plot(kind='line', color='blue')
GEN_UNRES_trump_sentDF.mean().plot(kind='line', color='purple')
INF_RES_trump_sentDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_trump_sentDF.mean().plot(kind='line', color='black')

plt.axhline(0, color="red", linestyle="--")
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Sentiment')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %% [markdown]
# **Clinton Sentiment**

# %%
plt.figure()

rb_clinton_sentDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Clinton Mention Sentiment')
GEN_RES_clinton_sentDF.mean().plot(kind='line', color='blue')
GEN_UNRES_clinton_sentDF.mean().plot(kind='line', color='purple')
INF_RES_clinton_sentDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_clinton_sentDF.mean().plot(kind='line', color='black')

plt.axhline(0, color="red", linestyle="--")
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Sentiment')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %% [markdown]
# **General Sentiment**

# %%
plt.figure()

rb_sentiment_scoresDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Monthly Sentiment')
GEN_RES_sentiment_scoresDF.mean().plot(kind='line', color='blue')
GEN_UNRES_sentiment_scoresDF.mean().plot(kind='line', color='purple')
INF_RES_sentiment_scoresDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_sentiment_scoresDF.mean().plot(kind='line', color='black')

plt.axhline(0, color="red", linestyle="--")
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Sentiment')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %%
plt.figure()

rb_positive_sentDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Positive Sentiment')
GEN_RES_positive_sentDF.mean().plot(kind='line', color='blue')
GEN_UNRES_positive_sentDF.mean().plot(kind='line', color='purple')
INF_RES_positive_sentDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_positive_sentDF.mean().plot(kind='line', color='black')

plt.axhline(0, color="red", linestyle="--")
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Sentiment')
plt.xlabel('Timeline (2014-2016)')
plt.show()

# %%
plt.figure()

rb_negative_sentDF.mean().plot(kind='line', color='green', figsize=(15,8),title='Mean Negative Sentiment')
GEN_RES_negative_sentDF.mean().plot(kind='line', color='blue')
GEN_UNRES_negative_sentDF.mean().plot(kind='line', color='purple')
INF_RES_negative_sentDF.mean().plot(kind='line', color='darkblue')
INF_UNRES_negative_sentDF.mean().plot(kind='line', color='black')

plt.axhline(0, color="red", linestyle="--")
plt.legend(('Random Baseline', 'Responsive, Low Follow Count Users', 'Unresponsive, Low Follow Count Users', 'Responsive, High Follow Count Users','Unresponsive, High Follow Count Users'))
plt.ylabel('Mean Monthly Sentiment')
plt.xlabel('Timeline (2014-2016)')
plt.show()
