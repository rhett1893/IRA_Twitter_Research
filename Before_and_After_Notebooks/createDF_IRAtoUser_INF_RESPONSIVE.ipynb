# %%
import csv
import numpy as np 
import pandas as pd
from datetime import datetime as dt
import pickle

pd.set_option('display.max_rows', 4000)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# **Get all user IDs**
#
# all user ids, stored in 'userID_dict' in the format of:
#
# userID_dict[user_id] = username

# %%
# temp1D = pd.read_csv("dict_1d_usernames.csv", low_memory=False)
temp2D = pd.read_csv("/home/updu6059/Twint_Data/ParallelProcessing/Famous_Users/MentionedBack_Users/Filtered_EnglishUsers_MentionedBackUsers_FINAL.csv", low_memory=False)

# temp1D.head()
temp2D.head()
# len(temp2D)
# Out:
#    Unnamed: 0            Users
# 0           0     Portland_jet
# 1           1  tannous_mouawad
# 2           2     violinhunter
# 3           3           LLH713
# 4           4    noprezzie2012

# %%
len(temp2D)
# Out:
# 481

# %%
import tweepy
# consumer_key = 'nnqF5rgtW0CKLjr2r4wLMdqMr'
# consumer_secret = 'Ny2LDN43ZB5WCGMkKpLwc2FXbFN9x43UwYeQzACmuA4W4zKsLS'
# access_token = '722619569760641025-mFPOJmQtCBwCg9d9LeQGUwFDdrPQCtE'
# access_token_secret = 'Xi4h0a1WpcmrKjfxtNTXYTvzximuF9FzzKDJOptPgOS7X'

consumer_key = 'bVgAX5fGidoy2IgPKHHgcfOG4'
consumer_secret = '83b6zN5HSIjPk7ALaGwcFY9DRwNEvOABgB0YD3TJI4KXigzJY9'
access_token = '48478289-5oNed2t3pcbO5aSt5DdeoeoOTfLUePQUYJ96tkkfd'
access_token_secret = 'VDOFj9IjC0r5QgbIu1kGgAp68fEwHjKLlhGJkBPFRNbXD'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
# user = api.get_user(screen_name = 'notnotrhett')
# user.id

# %%
userID_dict = {}

# for i in range(len(temp1D)):
#     userID_dict[temp1D['user_id'][i]] = temp1D['username'][i]

for i in range(len(temp2D)):
    try:
        user = api.get_user(screen_name = temp2D['Users'][i])
        userID_dict[user.id] = temp2D['Users'][i]
#         print(user.id)
    except tweepy.RateLimitError:
        print("RATE LIMIT HIT [" + str(i) + "]- " + temp1D['Users'][i])
        time.sleep(15 * 60)
        i -= 1
    except:
        print("User Failed - " + temp2D['Users'][i] + " [" + str(i) + "]")
    
len(userID_dict)
# Out:
# User Failed - hbg1x48 [28]
# User Failed - MSymbolik [118]
# User Failed - fairNtrue [231]
# User Failed - Use2020Vision [269]
# 477

# %% [markdown]
# **Read in IRA tweet set**

# %%
iraDF = pd.read_csv('ira_tweets_csv_unhashed.csv', low_memory=False)

# %%
print(len(iraDF))
# Out:
# 8768633

# %%
iraDF.tail(5)
# Out:
#                     tweetid      userid user_display_name user_screen_name  \
# 8768628  552931773240209408  2231059909   Невские Новости         NevnovPR
# 8768629  430175706794835968  2231059909   Невские Новости         NevnovPR
# 8768630  488096513516523521  2231059909   Невские Новости         NevnovPR
# 8768631  559036918319816704  1949085066          kpesmina         kpesmina
# 8768632  518502331537965056  1949085066          kpesmina         kpesmina
#
#         user_reported_location  \
# 8768628        Санкт-Петербург
# 8768629        Санкт-Петербург
# 8768630        Санкт-Петербург
# 8768631                 Манила
# 8768632                 Манила
#
#                                   user_profile_description  \
# 8768628  ИА Невские новости по районам. Самые свежие но...
# 8768629  ИА Невские новости по районам. Самые свежие но...
# 8768630  ИА Невские новости по районам. Самые свежие но...
# 8768631  Люблю гулять у воды. Пишу на когда как. Не люб...
# 8768632  Люблю гулять у воды. Пишу на когда как. Не люб...
#
#                user_profile_url  follower_count  following_count  \
# 8768628  http://t.co/vdTR6Tj1Iq            4693             2287
# 8768629  http://t.co/vdTR6Tj1Iq            4693             2287
# 8768630  http://t.co/vdTR6Tj1Iq            4693             2287
# 8768631  http://t.co/8TrkgDfbEy             558              453
# 8768632  http://t.co/8TrkgDfbEy             558              453
#
#         account_creation_date account_language tweet_language  \
# 8768628            2013-12-05               ru             ru
# 8768629            2013-12-05               ru             ru
# 8768630            2013-12-05               ru             ru
# 8768631            2013-10-09               ru             ru
# 8768632            2013-10-09               ru             ru
#
#                                                 tweet_text        tweet_time  \
# 8768628  На КАД автомобиль влетел в ограждение: пассажи...  2015-01-07 20:56
# 8768629  Финал Кубка Содружества: украинцы разгромили с...  2014-02-03 03:07
# 8768630  ГИБДД: Водитель фуры серьезно пострадал при па...  2014-07-12 23:04
# 8768631  RT @berdnikov: Обстрел Донецка и Луганска - эт...  2015-01-24 17:16
# 8768632  RT @LevSharansky: Мы, украинцы, изначально зна...  2014-10-04 20:46
#
#         tweet_client_name  in_reply_to_tweetid  in_reply_to_userid  \
# 8768628       twitterfeed                  NaN                 NaN
# 8768629       twitterfeed                  NaN                 NaN
# 8768630       twitterfeed                  NaN                 NaN
# 8768631          meceslav                  NaN                 NaN
# 8768632     newtwittersky                  NaN                 NaN
#
#          quoted_tweet_tweetid  is_retweet  retweet_userid  retweet_tweetid  \
# 8768628                   NaN       False             NaN              NaN
# 8768629                   NaN       False             NaN              NaN
# 8768630                   NaN       False             NaN              NaN
# 8768631                   NaN        True      17964137.0     5.590306e+17
# 8768632                   NaN        True     253261225.0     5.184983e+17
#
#          latitude  longitude  quote_count  reply_count  like_count  \
# 8768628       NaN        NaN          0.0          0.0         0.0
# 8768629       NaN        NaN          0.0          0.0         0.0
# 8768630       NaN        NaN          0.0          0.0         0.0
# 8768631       NaN        NaN          0.0          0.0         0.0
# 8768632       NaN        NaN          0.0          0.0         0.0
#
#          retweet_count hashtags                     urls user_mentions  \
# 8768628            0.0    [СПб]  [http://bit.ly/1xGnfB8]           NaN
# 8768629            1.0    [СПб]                      NaN           NaN
# 8768630            0.0    [СПб]                      NaN           NaN
# 8768631            0.0      NaN                      NaN    [17964137]
# 8768632            0.0      NaN                      NaN   [253261225]
#
#         poll_choices
# 8768628          NaN
# 8768629          NaN
# 8768630          NaN
# 8768631          NaN
# 8768632          NaN

# %% [markdown]
# **Create DataFrame for IRA -> User Contact Points**

# %%
contactPointsDF = pd.DataFrame(columns=['username','user_id','ira_username','ira_user_id',
                                       'tweet', 'tweet_date', 'meantions_list'])

# %% [markdown]
# **Loop through IRA data set, checking for contact with our current user set, if contact was established, add to contactPointsDF**

# %%
total = str(len(iraDF))
count = 1
#loop through ira tweet DF
for tweet in range(len(iraDF)):
    mention_string = str(iraDF['user_mentions'][tweet])
    #if mention list exists, save and reformat as it is a string not a list
    if mention_string != "[]" and mention_string != 'nan':  
        mention_list = mention_string.split(', ')
        mention_list[0] = mention_list[0][1:]
        mention_list[-1] = mention_list[-1][:-1]
        for x in range(len(mention_list)):
            mention_list[x] = int(mention_list[x])
#         for j in range(len(mention_list)):
#             mention_list[j] = int(mention_list[j])

        #check against user ids in our userID_dict
        for mention in mention_list:
            temp_key = mention
            if temp_key in userID_dict.keys():
#                 print("found!")
                #if a user id was mentioned, add to contactPointsDF
                contactPointsDF = contactPointsDF.append(
                    {'username' : userID_dict[temp_key],
                      'user_id' : temp_key,
                      'ira_username' : iraDF['user_screen_name'][tweet],
                      'ira_user_id' : iraDF['userid'][tweet],
                      'tweet' : iraDF['tweet_text'][tweet],
                      'tweet_date' : iraDF['tweet_time'][tweet],
                      'meantions_list' : mention_list,
                     }, ignore_index=True)
    if count % 10000 == 0:
        print(str(count) + " / " + total)
    count += 1
# Out:
# 10000 / 8768633
# 20000 / 8768633
# 30000 / 8768633
# 40000 / 8768633
# 50000 / 8768633
# 60000 / 8768633
# 70000 / 8768633
# 80000 / 8768633
# 90000 / 8768633
# 100000 / 8768633
# 110000 / 8768633
# 120000 / 8768633
# 130000 / 8768633
# 140000 / 8768633
# 150000 / 8768633
# 160000 / 8768633
# 170000 / 8768633
# 180000 / 8768633
# 190000 / 8768633
# 200000 / 8768633
# 210000 / 8768633
# 220000 / 8768633
# 230000 / 8768633
# 240000 / 8768633
# 250000 / 8768633
# 260000 / 8768633
# 270000 / 8768633
# 280000 / 8768633
# 290000 / 8768633
# 300000 / 8768633
# 310000 / 8768633
# 320000 / 8768633
# 330000 / 8768633
# 340000 / 8768633
# 350000 / 8768633
# 360000 / 8768633
# 370000 / 8768633
# 380000 / 8768633
# 390000 / 8768633
# 400000 / 8768633
# 410000 / 8768633
# 420000 / 8768633
# 430000 / 8768633
# 440000 / 8768633
# 450000 / 8768633
# 460000 / 8768633
# 470000 / 8768633
# 480000 / 8768633
# 490000 / 8768633
# 500000 / 8768633
# 510000 / 8768633
# 520000 / 8768633
# 530000 / 8768633
# 540000 / 8768633
# 550000 / 8768633
# 560000 / 8768633
# 570000 / 8768633
# 580000 / 8768633
# 590000 / 8768633
# 600000 / 8768633
# 610000 / 8768633
# 620000 / 8768633
# 630000 / 8768633
# 640000 / 8768633
# 650000 / 8768633
# 660000 / 8768633
# 670000 / 8768633
# 680000 / 8768633
# 690000 / 8768633
# 700000 / 8768633
# 710000 / 8768633
# 720000 / 8768633
# 730000 / 8768633
# 740000 / 8768633
# 750000 / 8768633
# 760000 / 8768633
# 770000 / 8768633
# 780000 / 8768633
# 790000 / 8768633
# 800000 / 8768633
# 810000 / 8768633
# 820000 / 8768633
# 830000 / 8768633
# 840000 / 8768633
# 850000 / 8768633
# 860000 / 8768633
# 870000 / 8768633
# 880000 / 8768633
# 890000 / 8768633
# 900000 / 8768633
# 910000 / 8768633
# 920000 / 8768633
# 930000 / 8768633
# 940000 / 8768633
# 950000 / 8768633
# 960000 / 8768633
# 970000 / 8768633
# 980000 / 8768633
# 990000 / 8768633
contactPointsDF.to_csv('contact_IRAtweets_Inf_RESPONSIVE.csv')

# %%
len(contactedUsers)
# Out:
# 477

# %%
contactDF = pd.DataFrame(columns=['username','user_id','ira_username','ira_user_id',
                                       'tweet', 'tweet_date', 'mentions_list'])

# %%
def get_key(val): 
    for key, value in userID_dict.items(): 
        if val == value: 
            return key

# %%
# print("hello")

# %%
size = str(len(contactedUsers))
count = 1
for user in contactedUsers:
    ira_username_temp = []
    ira_userid_temp = []
    tweet_temp = []
    tweet_date_temp = []
    mentions_list_temp = []
    for tweet in range(len(contactPointsDF)):
        if(contactPointsDF['username'][tweet] == user):
            ira_username_temp.append(contactPointsDF['ira_username'][tweet])
            ira_userid_temp.append(contactPointsDF['ira_user_id'][tweet])
            tweet_temp.append(contactPointsDF['tweet'][tweet])
            tweet_date_temp.append(contactPointsDF['tweet_date'][tweet])
            mentions_list_temp.append(contactPointsDF['meantions_list'][tweet])
    contactDF = contactDF.append(
                    {'username' : user,
                      'user_id' : get_key(user),
                      'ira_username' : ira_username_temp,
                      'ira_user_id' : ira_userid_temp,
                      'tweet' : tweet_temp,
                      'tweet_date' : tweet_date_temp,
                      'mentions_list' : mentions_list_temp,
                     }, ignore_index=True)
    print(str(count) + " / " + size)
    count += 1
# Out:
# 1 / 477
# 2 / 477
# 3 / 477
# 4 / 477
# 5 / 477
# 6 / 477
# 7 / 477
# 8 / 477
# 9 / 477
# 10 / 477
# 11 / 477
# 12 / 477
# 13 / 477
# 14 / 477
# 15 / 477
# 16 / 477
# 17 / 477
# 18 / 477
# 19 / 477
# 20 / 477
# 21 / 477
# 22 / 477
# 23 / 477
# 24 / 477
# 25 / 477
# 26 / 477
# 27 / 477
# 28 / 477
# 29 / 477
# 30 / 477
# 31 / 477
# 32 / 477
# 33 / 477
# 34 / 477
# 35 / 477
# 36 / 477
# 37 / 477
# 38 / 477
# 39 / 477
# 40 / 477
# 41 / 477
# 42 / 477
# 43 / 477
# 44 / 477
# 45 / 477
# 46 / 477
# 47 / 477
# 48 / 477
# 49 / 477
# 50 / 477
# 51 / 477
# 52 / 477
# 53 / 477
# 54 / 477
# 55 / 477
# 56 / 477
# 57 / 477
# 58 / 477
# 59 / 477
# 60 / 477
# 61 / 477
# 62 / 477
# 63 / 477
# 64 / 477
# 65 / 477
# 66 / 477
# 67 / 477
# 68 / 477
# 69 / 477
# 70 / 477
# 71 / 477
# 72 / 477
# 73 / 477
# 74 / 477
# 75 / 477
# 76 / 477
# 77 / 477
# 78 / 477
# 79 / 477
# 80 / 477
# 81 / 477
# 82 / 477
# 83 / 477
# 84 / 477
# 85 / 477
# 86 / 477
# 87 / 477
# 88 / 477
# 89 / 477
# 90 / 477
# 91 / 477
# 92 / 477
# 93 / 477
# 94 / 477
# 95 / 477
# 96 / 477
# 97 / 477
# 98 / 477
# 99 / 477
# 100 / 477
# 101 / 477
# 102 / 477
# 103 / 477
# 104 / 477
# 105 / 477
# 106 / 477
# 107 / 477
# 108 / 477
# 109 / 477
# 110 / 477
# 111 / 477
# 112 / 477
# 113 / 477
# 114 / 477
# 115 / 477
# 116 / 477
# 117 / 477
# 118 / 477
# 119 / 477
# 120 / 477
# 121 / 477
# 122 / 477
# 123 / 477
# 124 / 477
# 125 / 477
# 126 / 477
# 127 / 477
# 128 / 477
# 129 / 477
# 130 / 477
# 131 / 477
# 132 / 477
# 133 / 477
# 134 / 477
# 135 / 477
# 136 / 477
# 137 / 477
# 138 / 477
# 139 / 477
# 140 / 477
# 141 / 477
# 142 / 477
# 143 / 477
# 144 / 477
# 145 / 477
# 146 / 477
# 147 / 477
# 148 / 477
# 149 / 477
# 150 / 477
# 151 / 477
# 152 / 477
# 153 / 477
# 154 / 477
# 155 / 477
# 156 / 477
# 157 / 477
# 158 / 477
# 159 / 477
# 160 / 477
# 161 / 477
# 162 / 477
# 163 / 477
# 164 / 477
# 165 / 477
# 166 / 477
# 167 / 477
# 168 / 477
# 169 / 477
# 170 / 477
# 171 / 477
# 172 / 477
# 173 / 477
# 174 / 477
# 175 / 477
# 176 / 477
# 177 / 477
# 178 / 477
# 179 / 477
# 180 / 477
# 181 / 477
# 182 / 477
# 183 / 477
# 184 / 477
# 185 / 477
# 186 / 477
# 187 / 477
# 188 / 477
# 189 / 477
# 190 / 477
# 191 / 477
# 192 / 477
# 193 / 477
# 194 / 477
# 195 / 477
# 196 / 477
# 197 / 477
# 198 / 477
# 199 / 477
# 200 / 477
# 201 / 477
# 202 / 477
# 203 / 477
# 204 / 477
# 205 / 477
# 206 / 477
# 207 / 477
# 208 / 477
# 209 / 477
# 210 / 477
# 211 / 477
# 212 / 477
# 213 / 477
# 214 / 477
# 215 / 477
# 216 / 477
# 217 / 477
# 218 / 477
# 219 / 477
# 220 / 477
# 221 / 477
# 222 / 477
# 223 / 477
# 224 / 477
# 225 / 477
# 226 / 477
# 227 / 477
# 228 / 477
# 229 / 477
# 230 / 477
# 231 / 477
# 232 / 477
# 233 / 477
# 234 / 477
# 235 / 477
# 236 / 477
# 237 / 477
# 238 / 477
# 239 / 477
# 240 / 477
# 241 / 477
# 242 / 477
# 243 / 477
# 244 / 477
# 245 / 477
# 246 / 477
# 247 / 477
# 248 / 477
# 249 / 477
# 250 / 477
# 251 / 477
# 252 / 477
# 253 / 477
# 254 / 477
# 255 / 477
# 256 / 477
# 257 / 477
# 258 / 477
# 259 / 477
# 260 / 477
# 261 / 477
# 262 / 477
# 263 / 477
# 264 / 477
# 265 / 477
# 266 / 477
# 267 / 477
# 268 / 477
# 269 / 477
# 270 / 477
# 271 / 477
# 272 / 477
# 273 / 477
# 274 / 477
# 275 / 477
# 276 / 477
# 277 / 477
# 278 / 477
# 279 / 477
# 280 / 477
# 281 / 477
# 282 / 477
# 283 / 477
# 284 / 477
# 285 / 477
# 286 / 477
# 287 / 477
# 288 / 477
# 289 / 477
# 290 / 477
# 291 / 477
# 292 / 477
# 293 / 477
# 294 / 477
# 295 / 477
# 296 / 477
# 297 / 477
# 298 / 477
# 299 / 477
# 300 / 477
# 301 / 477
# 302 / 477
# 303 / 477
# 304 / 477
# 305 / 477
# 306 / 477
# 307 / 477
# 308 / 477
# 309 / 477
# 310 / 477
# 311 / 477
# 312 / 477
# 313 / 477
# 314 / 477
# 315 / 477
# 316 / 477
# 317 / 477
# 318 / 477
# 319 / 477
# 320 / 477
# 321 / 477
# 322 / 477
# 323 / 477
# 324 / 477
# 325 / 477
# 326 / 477
# 327 / 477
# 328 / 477
# 329 / 477
# 330 / 477
# 331 / 477
# 332 / 477
# 333 / 477
# 334 / 477
# 335 / 477
# 336 / 477
# 337 / 477
# 338 / 477
# 339 / 477
# 340 / 477
# 341 / 477
# 342 / 477
# 343 / 477
# 344 / 477
# 345 / 477
# 346 / 477
# 347 / 477
# 348 / 477
# 349 / 477
# 350 / 477
# 351 / 477
# 352 / 477
# 353 / 477
# 354 / 477
# 355 / 477
# 356 / 477
# 357 / 477
# 358 / 477
# 359 / 477
# 360 / 477
# 361 / 477
# 362 / 477
# 363 / 477
# 364 / 477
# 365 / 477
# 366 / 477
# 367 / 477
# 368 / 477
# 369 / 477
# 370 / 477
# 371 / 477
# 372 / 477
# 373 / 477
# 374 / 477
# 375 / 477
# 376 / 477
# 377 / 477
# 378 / 477
# 379 / 477
# 380 / 477
# 381 / 477
# 382 / 477
# 383 / 477
# 384 / 477
# 385 / 477
# 386 / 477
# 387 / 477
# 388 / 477
# 389 / 477
# 390 / 477
# 391 / 477
# 392 / 477
# 393 / 477
# 394 / 477
# 395 / 477
# 396 / 477
# 397 / 477
# 398 / 477
# 399 / 477
# 400 / 477
# 401 / 477
# 402 / 477
# 403 / 477
# 404 / 477
# 405 / 477
# 406 / 477
# 407 / 477
# 408 / 477
# 409 / 477
# 410 / 477
# 411 / 477
# 412 / 477
# 413 / 477
# 414 / 477
# 415 / 477
# 416 / 477
# 417 / 477
# 418 / 477
# 419 / 477
# 420 / 477
# 421 / 477
# 422 / 477
# 423 / 477
# 424 / 477
# 425 / 477
# 426 / 477
# 427 / 477
# 428 / 477
# 429 / 477
# 430 / 477
# 431 / 477
# 432 / 477
# 433 / 477
# 434 / 477
# 435 / 477
# 436 / 477
# 437 / 477
# 438 / 477
# 439 / 477
# 440 / 477
# 441 / 477
# 442 / 477
# 443 / 477
# 444 / 477
# 445 / 477
# 446 / 477
# 447 / 477
# 448 / 477
# 449 / 477
# 450 / 477
# 451 / 477
# 452 / 477
# 453 / 477
# 454 / 477
# 455 / 477
# 456 / 477
# 457 / 477
# 458 / 477
# 459 / 477
# 460 / 477
# 461 / 477
# 462 / 477
# 463 / 477
# 464 / 477
# 465 / 477
# 466 / 477
# 467 / 477
# 468 / 477
# 469 / 477
# 470 / 477
# 471 / 477
# 472 / 477
# 473 / 477
# 474 / 477
# 475 / 477
# 476 / 477
# 477 / 477

# %%
contactDF.to_csv('contact_IRAtoUser_Inf_RESPONSIVE.csv')

# %%
print(len(contactDF))
# Out:
# 477

# %%
len(contactDF.username.unique())
# Out:
# 477

# %%
contactDF.head()
# Out:
#        username     user_id  \
# 0  AnnoGalactic  1718608849
# 1         deray    29417304
# 2       samswey   791077327
# 3    ARnews1936  2845849081
# 4    TalibKweli    18511475
#
#                                         ira_username  \
# 0  [Tess_Snider, AmandaVGreen, claudia42kern, hol...
# 1  [OliviaDWarren, RegieBlackmon, lagonehoe, Zzza...
# 2  [NoJonathonNo, mrclydepratt, GwennyThot, Stanl...
# 3  [PrettyLaraPlace, AmelieBaldwin, JeffreyKahuna...
# 4  [HunterOddddom, RegieBlackmon, BigSeanBeast, J...
#
#                                          ira_user_id  \
# 0  [1663407794, 2616344667, 1664988493, 254059659...
# 1  [1649719753, 1691736218, 1510488662, 170195542...
# 2  [1518857420, 1768259989, 1677048979, 168577176...
# 3  [1533813962, 1679279490, 1623180199, 153381396...
# 4  [1720981580, 1691736218, 1621376306, 162709680...
#
#                                                tweet  \
# 0  [RT @AnnoGalactic: #AlternativeUsesForABoner  ...
# 1  [RT @Slamabrewski: @deray The other trials are...
# 2  [RT @unrprofessor: @samswey unveils plan to en...
# 3  [RT @ARnews1936: Iraqi general says 70 percent...
# 4  [RT @TalibKweli: RT @XolaniMvulana: @TarekFata...
#
#                                           tweet_date  \
# 0  [2015-10-08 08:41, 2017-01-30 12:31, 2016-09-1...
# 1  [2015-12-16 23:29, 2017-07-06 19:31, 2017-07-2...
# 2  [2016-10-25 18:09, 2017-05-02 01:26, 2017-01-2...
# 3  [2017-01-05 13:05, 2016-12-08 04:43, 2017-02-2...
# 4  [2016-08-23 14:39, 2017-07-19 08:52, 2016-08-2...
#
#                                        mentions_list
# 0  [[1718608849], [1718608849, 2730763873], [1718...
# 1  [[1696560656, 29417304], [29417304], [29417304...
# 2  [[870393260, 791077327], [791077327], [7910773...
# 3  [[2845849081], [2845849081], [2845849081], [28...
# 4  [[18511475, 586513204, 17537467], [18511475], ...

# %%
# for i in range(len(contactDF)):
#     if contactDF['username'][i] == 'Borisovalustnah':
#         print(str(i))

# %%
# print(str(len(contactDF) - 2265))

# %%
newContactDF = contactDF

# %%
len(contactDF)
# Out:
# 477

# %%
newContactDF.tail()
# Out:
#            username             user_id  \
# 472          jmb063            58685992
# 473       Elle_Vien           478289798
# 474  TrydecafCoffey  840701960131076096
# 475   Para_glider69           591451860
# 476     SaadAbedine            17325149
#
#                                         ira_username  \
# 472               [ItsTimeToSecede, ItsTimeToSecede]
# 473  [PatriotBlake, PamelaKealer13, colinsneverland]
# 474               [CovfefeNationUS, CovfefeNationUS]
# 475  [AmelieBaldwin, Kelvin_Chambers, SouthLoneStar]
# 476                     [BrianTheLifter, muhsansins]
#
#                                   ira_user_id  \
# 472                  [4271904983, 4271904983]
# 473      [2671070290, 4437444442, 1647457314]
# 474  [743166519157227520, 743166519157227520]
# 475      [1679279490, 1695830984, 4355797094]
# 476                  [1675280893, 3053424600]
#
#                                                  tweet  \
# 472  [@jmb063 we're organizing a #texit rally, it's...
# 473  [RT @Elle_Vien: TweetDaily-BRING THEM HOME! #F...
# 474  [@TrydecafCoffey @RepublicanChick Those libera...
# 475  [RT @Para_glider69: Trump isn't against free t...
# 476  [RT @SaadAbedine: Kryptonite of Arab world's p...
#
#                                             tweet_date  \
# 472               [2016-10-26 02:41, 2016-10-26 02:40]
# 473  [2015-12-10 15:27, 2015-12-13 23:58, 2015-12-1...
# 474               [2017-04-22 02:40, 2017-04-22 02:39]
# 475  [2017-01-21 10:13, 2017-04-16 08:23, 2016-07-1...
# 476               [2017-08-02 17:29, 2015-10-18 08:43]
#
#                                          mentions_list
# 472                           [[58685992], [58685992]]
# 473  [[478289798, 30313925, 813286, 9624742, 150071...
# 474  [[840701960131076096, 582135529, 216776631], [...
# 475  [[591451860], [591451860], [591451860, 19439570]]
# 476                 [[17325149, 66959303], [17325149]]

# %%
newContactDF= newContactDF.reset_index()

# %%
newContactDF = newContactDF.drop(['index'], axis=1)
newContactDF.head()
# Out:
#        username     user_id  \
# 0  AnnoGalactic  1718608849
# 1         deray    29417304
# 2       samswey   791077327
# 3    ARnews1936  2845849081
# 4    TalibKweli    18511475
#
#                                         ira_username  \
# 0  [Tess_Snider, AmandaVGreen, claudia42kern, hol...
# 1  [OliviaDWarren, RegieBlackmon, lagonehoe, Zzza...
# 2  [NoJonathonNo, mrclydepratt, GwennyThot, Stanl...
# 3  [PrettyLaraPlace, AmelieBaldwin, JeffreyKahuna...
# 4  [HunterOddddom, RegieBlackmon, BigSeanBeast, J...
#
#                                          ira_user_id  \
# 0  [1663407794, 2616344667, 1664988493, 254059659...
# 1  [1649719753, 1691736218, 1510488662, 170195542...
# 2  [1518857420, 1768259989, 1677048979, 168577176...
# 3  [1533813962, 1679279490, 1623180199, 153381396...
# 4  [1720981580, 1691736218, 1621376306, 162709680...
#
#                                                tweet  \
# 0  [RT @AnnoGalactic: #AlternativeUsesForABoner  ...
# 1  [RT @Slamabrewski: @deray The other trials are...
# 2  [RT @unrprofessor: @samswey unveils plan to en...
# 3  [RT @ARnews1936: Iraqi general says 70 percent...
# 4  [RT @TalibKweli: RT @XolaniMvulana: @TarekFata...
#
#                                           tweet_date  \
# 0  [2015-10-08 08:41, 2017-01-30 12:31, 2016-09-1...
# 1  [2015-12-16 23:29, 2017-07-06 19:31, 2017-07-2...
# 2  [2016-10-25 18:09, 2017-05-02 01:26, 2017-01-2...
# 3  [2017-01-05 13:05, 2016-12-08 04:43, 2017-02-2...
# 4  [2016-08-23 14:39, 2017-07-19 08:52, 2016-08-2...
#
#                                        mentions_list
# 0  [[1718608849], [1718608849, 2730763873], [1718...
# 1  [[1696560656, 29417304], [29417304], [29417304...
# 2  [[870393260, 791077327], [791077327], [7910773...
# 3  [[2845849081], [2845849081], [2845849081], [28...
# 4  [[18511475, 586513204, 17537467], [18511475], ...

# %%
# newContactDF.to_csv('contact_IRAtoUser.csv')

# %%
# testing = newContactDF['mentions_list'][1]

# %%
# len(testing)

# %%
# tempdf = newContactDF
# tempdf['new'] = 0
# tempdf.head()

# %%
newContactDF['contact_points'] = 0
# print(testing[0][0])
for h in range(len(newContactDF)):
# for h in range(100):
    testing = newContactDF['mentions_list'][h]
    temp = []
    for k in range(len(testing)):
        for l in range(len(testing[k])):
            temp.append(testing[k][l])
    newContactDF['mentions_list'][h] = temp
    newContactDF['contact_points'][h] = len(temp)
#     print(temp)
# Out:
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/rhetthanscom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# newContactDF[100:200]

# %%
len(newContactDF)
# Out:
# 477

# %%
# print(temp)

# %%
newContactDF.to_csv('contact_IRAtoUser_Inf_RESPONSIVE.csv')
